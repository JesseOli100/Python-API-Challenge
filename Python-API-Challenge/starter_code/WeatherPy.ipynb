# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 573

# %%
cities
# Out:
# ['adamstown',
#  'yalta',
#  'nuuk',
#  'wailua homesteads',
#  'edinburgh of the seven seas',
#  'puerto natales',
#  'hami',
#  'thompson',
#  'papatowai',
#  'kindu',
#  'olonkinbyen',
#  'blackmans bay',
#  'cruzeiro do sul',
#  'bethel',
#  'yellowknife',
#  'newman',
#  'alotau',
#  'gadzhiyevo',
#  'iwon-up',
#  'portland',
#  'namdrik',
#  'lewistown',
#  'talnakh',
#  'keflavik',
#  'ribeira grande',
#  'whitehorse',
#  'talara',
#  'cabo san lucas',
#  'lihue',
#  'longyearbyen',
#  'utrik',
#  'slave lake',
#  'port alfred',
#  'hawaiian paradise park',
#  'crane',
#  'susuman',
#  'vadso',
#  'ushuaia',
#  'grytviken',
#  'minas de marcona',
#  'iqaluit',
#  'petropavlovsk-kamchatsky',
#  'port-aux-francais',
#  'alice springs',
#  'waingapu',
#  'kodiak',
#  'skutskar',
#  'kailua-kona',
#  'sandakan',
#  'waitangi',
#  'daoukro',
#  'jayapura',
#  'tongouson',
#  'guerrero negro',
#  'rio preto da eva',
#  'margaret river',
#  'valle de la pascua',
#  'axim',
#  'port elizabeth',
#  'zuni pueblo',
#  'fonte boa',
#  'zeya',
#  'selfoss',
#  'tateyama',
#  'mata de sao joao',
#  'taiohae',
#  'dudinka',
#  'foz do sousa',
#  'chardara',
#  'ust-nera',
#  'bao loc',
#  'namibe',
#  'eket',
#  'zambezi',
#  'touros',
#  'baishan',
#  'jamestown',
#  'arno',
#  'al ghayzah',
#  'olyokminsk',
#  'bredasdorp',
#  'san julian',
#  'qaqortoq',
#  'tsengel',
#  'saipan',
#  'malango',
#  'hammerfest',
#  'ntcheu',
#  'queenstown',
#  'antofagasta',
#  'hithadhoo',
#  'farafangana',
#  'vilyuchinsk',
#  'west island',
#  'tucuma',
#  'ta`u',
#  'puerto ayora',
#  'ceeldheer',
#  'puerto leguizamo',
#  'piacabucu',
#  'bubaque',
#  'peterborough',
#  'tazovsky',
#  'yemetsk',
#  'sai buri',
#  "'ohonua",
#  'bonthe',
#  'remire-montjoly',
#  'college',
#  'udachny',
#  'albany',
#  'galesong',
#  'roccella ionica',
#  'myeik',
#  'el aioun',
#  'treasure island',
#  'khandyga',
#  'ilulissat',
#  'tucurui',
#  'makokou',
#  'aral',
#  'chonchi',
#  'polyarnyy',
#  'melekeok village',
#  'lloydminster',
#  'lazaro cardenas',
#  'badger',
#  'smiltene',
#  'vershino-darasunskiy',
#  'invercargill',
#  'saint-joseph',
#  'vorkuta',
#  'mejit',
#  'flying fish cove',
#  'fisterra',
#  'east london',
#  'arcadia',
#  'enewetak',
#  'isafjordur',
#  'bikenibeu village',
#  'paramirim',
#  'taghazout',
#  'westport',
#  'vila velha',
#  'huarmey',
#  'constantia',
#  'akureyri',
#  'hirara',
#  'avarua',
#  'fort st. john',
#  'kingscliff',
#  'chegdomyn',
#  'barra de santo antonio',
#  'nogliki',
#  'weno',
#  'yeed',
#  'kristiansund',
#  'altamira',
#  'vingt cinq',
#  'wuhai',
#  'mityana',
#  'myitkyina',
#  'puerto baquerizo moreno',
#  'fale old settlement',
#  'usogorsk',
#  'nantucket',
#  'kot isa khan',
#  'tazacorte',
#  'rosa zarate',
#  'ghat',
#  'kruisfontein',
#  'khandud',
#  'taoudenni',
#  'borgarnes',
#  'nemuro',
#  'tiksi',
#  'klyuchi',
#  'necochea',
#  "nar'yan-mar",
#  'lebu',
#  'belaya kholunitsa',
#  'takab',
#  'alexandria',
#  'anadyr',
#  'taveta',
#  'aasiaat',
#  'bilibino',
#  'padre bernardo',
#  'prado',
#  'gaspe',
#  'hermanus',
#  'cannonvale',
#  'regina',
#  "mikun'",
#  'ad dilam',
#  'la passe',
#  'egilsstadir',
#  'sitka',
#  'trinity beach',
#  'likiep',
#  'ancud',
#  'cascais',
#  'rongelap',
#  'pospelikha',
#  'yangshuo',
#  'woolgoolga',
#  'kangding',
#  'margate',
#  'boende',
#  'buala',
#  'port lincoln',
#  'bardai',
#  'ahau',
#  "la'ie",
#  'aykhal',
#  'mongo',
#  'hanceville',
#  'porto murtinho',
#  'port mathurin',
#  'revelstoke',
#  'bechar',
#  'kivertsi',
#  'salinopolis',
#  'am timan',
#  'lata',
#  'tamanrasset',
#  'codrington',
#  'afaahiti',
#  'sao joao da barra',
#  'chilliwack',
#  'yuzhno-kurilsk',
#  'zolotonosha',
#  'fortuna',
#  'porto novo',
#  'vernon',
#  'vorgashor',
#  'betio village',
#  'rakops',
#  'leticia',
#  'inari',
#  'ulladulla',
#  'borogontsy',
#  'hell-ville',
#  'alesund',
#  'ayr',
#  'vorozhba',
#  'champua',
#  'starobin',
#  'al fallujah',
#  'yurga',
#  'igarka',
#  'inhambane',
#  'mena',
#  'lauro de freitas',
#  'prince rupert',
#  'souillac',
#  'dolores',
#  'stanley',
#  'punta arenas',
#  'aspen',
#  'janeng',
#  'tolanaro',
#  'kujang-up',
#  'menemen',
#  'concepcion del oro',
#  'haiku-pauwela',
#  'saldanha',
#  'mirny',
#  'palo alto',
#  'kavieng',
#  'gemena',
#  'copiapo',
#  'brookings',
#  'oskarshamn',
#  'al bawiti',
#  'cidreira',
#  'praia da vitoria',
#  'korets',
#  'arraial do cabo',
#  'orrville',
#  'mao',
#  'allapalli',
#  'broome',
#  'dryden',
#  'forster',
#  'ugoofaaru',
#  'sao vicente',
#  'zomin shaharchasi',
#  'kolonia',
#  'sao jose da coroa grande',
#  "st. john's",
#  'neon karlovasion',
#  'sur',
#  'howrah',
#  'northam',
#  'hafar al-batin',
#  'geraldton',
#  'pontes e lacerda',
#  'yaren',
#  'inirida',
#  'swakopmund',
#  'kingston',
#  'farmington',
#  'bathsheba',
#  'rosarito',
#  'chibougamau',
#  'villefranche-de-rouergue',
#  'atafu village',
#  "kapa'a",
#  'papao',
#  'ketchikan',
#  'saint-philippe',
#  'kudahuvadhoo',
#  'vegachi',
#  'koryazhma',
#  'mishelevka',
#  'roma',
#  'asubulaq',
#  'luderitz',
#  'port moresby',
#  'hamilton',
#  'iranshahr',
#  'dapa',
#  'tabuk',
#  'darreh shahr',
#  'wainwright',
#  'kodok',
#  'fedorovskiy',
#  'georgetown',
#  'ixtapa',
#  'siwa oasis',
#  'shimoda',
#  'dunedin',
#  'dazhong',
#  'kapuskasing',
#  'iskateley',
#  'waddan',
#  'neiafu',
#  'puerto armuelles',
#  'tura',
#  'hadibu',
#  'burang',
#  'pakokku',
#  'tsiombe',
#  'la mitra',
#  'mokhotlong',
#  'moengo',
#  'sofifi',
#  'cockburn town',
#  'leava',
#  'nurmijarvi',
#  'tangancicuaro de arista',
#  'yigo village',
#  'posto fiscal rolim de moura',
#  'mukalla',
#  'zouerate',
#  'meadow lakes',
#  'lae',
#  'niafunke',
#  'sukhothai',
#  'mar del plata',
#  'hiratacho',
#  'rimus',
#  'auki',
#  'tanjung pandan',
#  'kulhudhuffushi',
#  'gulf shores',
#  'pisco',
#  'alofi',
#  'tobelo',
#  'kharkhorin',
#  'makarov',
#  'aoulef',
#  'wittstock',
#  'buka',
#  'callao',
#  'naro moru',
#  'el calafate',
#  'fairmont',
#  'general villegas',
#  'ahlat',
#  'torghay',
#  'mount gambier',
#  'malabar',
#  'mata-utu',
#  'tanrake village',
#  'labrador city',
#  'mwatate',
#  'mili',
#  'areia',
#  'mogadishu',
#  'yanbu',
#  'vila franca do campo',
#  'lorengau',
#  'san luis de la loma',
#  'labuan',
#  'lodwar',
#  'west fargo',
#  'nema',
#  'coquimbo',
#  'kutum',
#  'san rafael del yuma',
#  'tranovaho',
#  'matoury',
#  'sisimiut',
#  'borgo',
#  'djibo',
#  'pangai',
#  'levelland',
#  "nuku'alofa",
#  'el banco',
#  'argo',
#  'arkhipo-osipovka',
#  'malvan',
#  'calama',
#  'dieppe',
#  'eldama ravine',
#  'camana',
#  'gebeit',
#  'itacare',
#  'kuala pilah',
#  'harenkarspel',
#  'bria',
#  'kearney',
#  'latakia',
#  'tibanbang',
#  'takoradi',
#  'itupiranga',
#  'pucallpa',
#  'huoqiu chengguanzhen',
#  'nouadhibou',
#  'erwin',
#  'rumonge',
#  'new norfolk',
#  'cova figueira',
#  'mount isa',
#  'darnah',
#  'cadale',
#  'luganville',
#  'nova vicosa',
#  'kone',
#  'fort bragg',
#  'sinabang',
#  'vikulovo',
#  'nova sintra',
#  'videira',
#  'mandalgovi',
#  'daru',
#  'black point',
#  'kulia village',
#  'ataq',
#  'lospalos',
#  'tashtagol',
#  'puerto san carlos',
#  'sonsorol village',
#  'labytnangi',
#  'raduzhny',
#  'isabela',
#  "qal'at bishah",
#  'stradella',
#  'las khorey',
#  'erenhot',
#  'yicheng',
#  'qom',
#  'sinop',
#  'fauske',
#  'am djarass',
#  'kill devil hills',
#  'ola',
#  'mount pearl',
#  'ouadda',
#  'ngunut',
#  'kuala tungkal',
#  'lerwick',
#  'serowe',
#  'san antonio de pale',
#  'shenjiamen',
#  'blackwater',
#  'darwin',
#  'dhidhdhoo',
#  'el abiodh sidi cheikh',
#  'enterprise',
#  'carnarvon',
#  'wanlaweyn',
#  'sogndal',
#  'coari',
#  'umm al quwain city',
#  "magistral'nyy",
#  'yenangyaung',
#  'siocon',
#  'tiruvottiyur',
#  'bandarbeyla',
#  'narvik',
#  'pamandzi',
#  'naze',
#  'turabah',
#  'belyy yar',
#  'chake chake',
#  'okahandja',
#  'selters',
#  'toga village',
#  'hard bargain',
#  'tshikapa',
#  'katsuura',
#  'pirenopolis',
#  'languyan',
#  "ust'-ilimsk",
#  'aboso',
#  'ishinomaki',
#  'tobi village',
#  'altkirch',
#  'port-vila',
#  'kavaratti',
#  'rio grande',
#  'hasaki',
#  'woodlake',
#  'goundam',
#  'toliara',
#  'mhamid',
#  'cargados carajos',
#  'toro',
#  'kataragama',
#  'achinsk',
#  'dakhla',
#  "samus'",
#  'qingyuan',
#  'manismata',
#  'merizo village',
#  'suva',
#  'hoquiam',
#  'harper',
#  'tongliao',
#  'tevragh zeina',
#  'labuan lombok',
#  'linhares',
#  'texarkana',
#  'floro',
#  'zuyevka',
#  'antu',
#  'zag',
#  'maragogi',
#  'conde',
#  'ouellah',
#  'taro',
#  'socorro',
#  'el fasher',
#  'tidjikja',
#  'grojec',
#  'kermanshah',
#  'abepura',
#  'sanislau',
#  'new plymouth',
#  'empangeni',
#  'horta',
#  'santa terezinha',
#  "yelan'-koleno",
#  'ribadeo',
#  'saffron walden',
#  'mbandaka',
#  'kyzyl-suu',
#  'jiuquan',
#  'gilgit',
#  'laojunmiao',
#  'shaydon',
#  'cabedelo',
#  'segezha',
#  'scarborough',
#  'bandar-e genaveh',
#  'vilhena',
#  'nadi',
#  'opuwo',
#  'riviere-du-loup',
#  'guangyuan']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = 'https://api.openweathermap.org/data/2.5/weather?'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&units=metric&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))


     # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
    # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()


        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date
                         })

   # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | yalta
# Processing Record 3 of Set 1 | nuuk
# Processing Record 4 of Set 1 | wailua homesteads
# Processing Record 5 of Set 1 | edinburgh of the seven seas
# Processing Record 6 of Set 1 | puerto natales
# Processing Record 7 of Set 1 | hami
# Processing Record 8 of Set 1 | thompson
# Processing Record 9 of Set 1 | papatowai
# Processing Record 10 of Set 1 | kindu
# Processing Record 11 of Set 1 | olonkinbyen
# Processing Record 12 of Set 1 | blackmans bay
# Processing Record 13 of Set 1 | cruzeiro do sul
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | newman
# Processing Record 17 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 18 of Set 1 | gadzhiyevo
# Processing Record 19 of Set 1 | iwon-up
# Processing Record 20 of Set 1 | portland
# Processing Record 21 of Set 1 | namdrik
# Processing Record 22 of Set 1 | lewistown
# Processing Record 23 of Set 1 | talnakh
# Processing Record 24 of Set 1 | keflavik
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | whitehorse
# Processing Record 27 of Set 1 | talara
# Processing Record 28 of Set 1 | cabo san lucas
# Processing Record 29 of Set 1 | lihue
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | utrik
# Processing Record 32 of Set 1 | slave lake
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | hawaiian paradise park
# Processing Record 35 of Set 1 | crane
# Processing Record 36 of Set 1 | susuman
# Processing Record 37 of Set 1 | vadso
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | grytviken
# Processing Record 40 of Set 1 | minas de marcona
# Processing Record 41 of Set 1 | iqaluit
# Processing Record 42 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 43 of Set 1 | port-aux-francais
# Processing Record 44 of Set 1 | alice springs
# Processing Record 45 of Set 1 | waingapu
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | skutskar
# City not found. Skipping...
# Processing Record 48 of Set 1 | kailua-kona
# Processing Record 49 of Set 1 | sandakan
# Processing Record 50 of Set 1 | waitangi
# Processing Record 0 of Set 2 | daoukro
# Processing Record 1 of Set 2 | jayapura
# Processing Record 2 of Set 2 | tongouson
# Processing Record 3 of Set 2 | guerrero negro
# Processing Record 4 of Set 2 | rio preto da eva
# Processing Record 5 of Set 2 | margaret river
# Processing Record 6 of Set 2 | valle de la pascua
# Processing Record 7 of Set 2 | axim
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | zuni pueblo
# Processing Record 10 of Set 2 | fonte boa
# Processing Record 11 of Set 2 | zeya
# Processing Record 12 of Set 2 | selfoss
# Processing Record 13 of Set 2 | tateyama
# Processing Record 14 of Set 2 | mata de sao joao
# Processing Record 15 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 16 of Set 2 | dudinka
# Processing Record 17 of Set 2 | foz do sousa
# Processing Record 18 of Set 2 | chardara
# Processing Record 19 of Set 2 | ust-nera
# Processing Record 20 of Set 2 | bao loc
# City not found. Skipping...
# Processing Record 21 of Set 2 | namibe
# Processing Record 22 of Set 2 | eket
# Processing Record 23 of Set 2 | zambezi
# Processing Record 24 of Set 2 | touros
# Processing Record 25 of Set 2 | baishan
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | arno
# Processing Record 28 of Set 2 | al ghayzah
# Processing Record 29 of Set 2 | olyokminsk
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | san julian
# Processing Record 32 of Set 2 | qaqortoq
# Processing Record 33 of Set 2 | tsengel
# Processing Record 34 of Set 2 | saipan
# Processing Record 35 of Set 2 | malango
# Processing Record 36 of Set 2 | hammerfest
# Processing Record 37 of Set 2 | ntcheu
# Processing Record 38 of Set 2 | queenstown
# Processing Record 39 of Set 2 | antofagasta
# Processing Record 40 of Set 2 | hithadhoo
# Processing Record 41 of Set 2 | farafangana
# Processing Record 42 of Set 2 | vilyuchinsk
# Processing Record 43 of Set 2 | west island
# Processing Record 44 of Set 2 | tucuma
# Processing Record 45 of Set 2 | ta`u
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | ceeldheer
# Processing Record 48 of Set 2 | puerto leguizamo
# Processing Record 49 of Set 2 | piacabucu
# Processing Record 0 of Set 3 | bubaque
# Processing Record 1 of Set 3 | peterborough
# Processing Record 2 of Set 3 | tazovsky
# Processing Record 3 of Set 3 | yemetsk
# Processing Record 4 of Set 3 | sai buri
# Processing Record 5 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 6 of Set 3 | bonthe
# Processing Record 7 of Set 3 | remire-montjoly
# Processing Record 8 of Set 3 | college
# Processing Record 9 of Set 3 | udachny
# Processing Record 10 of Set 3 | albany
# Processing Record 11 of Set 3 | galesong
# Processing Record 12 of Set 3 | roccella ionica
# Processing Record 13 of Set 3 | myeik
# Processing Record 14 of Set 3 | el aioun
# Processing Record 15 of Set 3 | treasure island
# Processing Record 16 of Set 3 | khandyga
# Processing Record 17 of Set 3 | ilulissat
# Processing Record 18 of Set 3 | tucurui
# Processing Record 19 of Set 3 | makokou
# Processing Record 20 of Set 3 | aral
# Processing Record 21 of Set 3 | chonchi
# Processing Record 22 of Set 3 | polyarnyy
# Processing Record 23 of Set 3 | melekeok village
# Processing Record 24 of Set 3 | lloydminster
# Processing Record 25 of Set 3 | lazaro cardenas
# Processing Record 26 of Set 3 | badger
# Processing Record 27 of Set 3 | smiltene
# Processing Record 28 of Set 3 | vershino-darasunskiy
# Processing Record 29 of Set 3 | invercargill
# Processing Record 30 of Set 3 | saint-joseph
# Processing Record 31 of Set 3 | vorkuta
# Processing Record 32 of Set 3 | mejit
# Processing Record 33 of Set 3 | flying fish cove
# Processing Record 34 of Set 3 | fisterra
# Processing Record 35 of Set 3 | east london
# Processing Record 36 of Set 3 | arcadia
# Processing Record 37 of Set 3 | enewetak
# Processing Record 38 of Set 3 | isafjordur
# Processing Record 39 of Set 3 | bikenibeu village
# Processing Record 40 of Set 3 | paramirim
# Processing Record 41 of Set 3 | taghazout
# Processing Record 42 of Set 3 | westport
# Processing Record 43 of Set 3 | vila velha
# Processing Record 44 of Set 3 | huarmey
# Processing Record 45 of Set 3 | constantia
# Processing Record 46 of Set 3 | akureyri
# Processing Record 47 of Set 3 | hirara
# Processing Record 48 of Set 3 | avarua
# Processing Record 49 of Set 3 | fort st. john
# Processing Record 0 of Set 4 | kingscliff
# Processing Record 1 of Set 4 | chegdomyn
# Processing Record 2 of Set 4 | barra de santo antonio
# Processing Record 3 of Set 4 | nogliki
# Processing Record 4 of Set 4 | weno
# Processing Record 5 of Set 4 | yeed
# Processing Record 6 of Set 4 | kristiansund
# Processing Record 7 of Set 4 | altamira
# Processing Record 8 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 9 of Set 4 | wuhai
# Processing Record 10 of Set 4 | mityana
# Processing Record 11 of Set 4 | myitkyina
# Processing Record 12 of Set 4 | puerto baquerizo moreno
# Processing Record 13 of Set 4 | fale old settlement
# Processing Record 14 of Set 4 | usogorsk
# Processing Record 15 of Set 4 | nantucket
# Processing Record 16 of Set 4 | kot isa khan
# Processing Record 17 of Set 4 | tazacorte
# Processing Record 18 of Set 4 | rosa zarate
# Processing Record 19 of Set 4 | ghat
# Processing Record 20 of Set 4 | kruisfontein
# Processing Record 21 of Set 4 | khandud
# Processing Record 22 of Set 4 | taoudenni
# Processing Record 23 of Set 4 | borgarnes
# Processing Record 24 of Set 4 | nemuro
# Processing Record 25 of Set 4 | tiksi
# Processing Record 26 of Set 4 | klyuchi
# Processing Record 27 of Set 4 | necochea
# Processing Record 28 of Set 4 | nar'yan-mar
# Processing Record 29 of Set 4 | lebu
# Processing Record 30 of Set 4 | belaya kholunitsa
# Processing Record 31 of Set 4 | takab
# Processing Record 32 of Set 4 | alexandria
# Processing Record 33 of Set 4 | anadyr
# Processing Record 34 of Set 4 | taveta
# Processing Record 35 of Set 4 | aasiaat
# Processing Record 36 of Set 4 | bilibino
# Processing Record 37 of Set 4 | padre bernardo
# Processing Record 38 of Set 4 | prado
# Processing Record 39 of Set 4 | gaspe
# Processing Record 40 of Set 4 | hermanus
# Processing Record 41 of Set 4 | cannonvale
# Processing Record 42 of Set 4 | regina
# Processing Record 43 of Set 4 | mikun'
# Processing Record 44 of Set 4 | ad dilam
# Processing Record 45 of Set 4 | la passe
# Processing Record 46 of Set 4 | egilsstadir
# Processing Record 47 of Set 4 | sitka
# Processing Record 48 of Set 4 | trinity beach
# Processing Record 49 of Set 4 | likiep
# Processing Record 0 of Set 5 | ancud
# Processing Record 1 of Set 5 | cascais
# Processing Record 2 of Set 5 | rongelap
# Processing Record 3 of Set 5 | pospelikha
# Processing Record 4 of Set 5 | yangshuo
# Processing Record 5 of Set 5 | woolgoolga
# Processing Record 6 of Set 5 | kangding
# Processing Record 7 of Set 5 | margate
# Processing Record 8 of Set 5 | boende
# Processing Record 9 of Set 5 | buala
# Processing Record 10 of Set 5 | port lincoln
# Processing Record 11 of Set 5 | bardai
# Processing Record 12 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 13 of Set 5 | la'ie
# Processing Record 14 of Set 5 | aykhal
# Processing Record 15 of Set 5 | mongo
# Processing Record 16 of Set 5 | hanceville
# Processing Record 17 of Set 5 | porto murtinho
# Processing Record 18 of Set 5 | port mathurin
# Processing Record 19 of Set 5 | revelstoke
# Processing Record 20 of Set 5 | bechar
# Processing Record 21 of Set 5 | kivertsi
# Processing Record 22 of Set 5 | salinopolis
# Processing Record 23 of Set 5 | am timan
# Processing Record 24 of Set 5 | lata
# Processing Record 25 of Set 5 | tamanrasset
# Processing Record 26 of Set 5 | codrington
# Processing Record 27 of Set 5 | afaahiti
# Processing Record 28 of Set 5 | sao joao da barra
# Processing Record 29 of Set 5 | chilliwack
# Processing Record 30 of Set 5 | yuzhno-kurilsk
# Processing Record 31 of Set 5 | zolotonosha
# Processing Record 32 of Set 5 | fortuna
# Processing Record 33 of Set 5 | porto novo
# Processing Record 34 of Set 5 | vernon
# Processing Record 35 of Set 5 | vorgashor
# Processing Record 36 of Set 5 | betio village
# Processing Record 37 of Set 5 | rakops
# Processing Record 38 of Set 5 | leticia
# Processing Record 39 of Set 5 | inari
# Processing Record 40 of Set 5 | ulladulla
# Processing Record 41 of Set 5 | borogontsy
# Processing Record 42 of Set 5 | hell-ville
# Processing Record 43 of Set 5 | alesund
# Processing Record 44 of Set 5 | ayr
# Processing Record 45 of Set 5 | vorozhba
# Processing Record 46 of Set 5 | champua
# Processing Record 47 of Set 5 | starobin
# Processing Record 48 of Set 5 | al fallujah
# Processing Record 49 of Set 5 | yurga
# Processing Record 0 of Set 6 | igarka
# Processing Record 1 of Set 6 | inhambane
# Processing Record 2 of Set 6 | mena
# Processing Record 3 of Set 6 | lauro de freitas
# Processing Record 4 of Set 6 | prince rupert
# Processing Record 5 of Set 6 | souillac
# Processing Record 6 of Set 6 | dolores
# Processing Record 7 of Set 6 | stanley
# Processing Record 8 of Set 6 | punta arenas
# Processing Record 9 of Set 6 | aspen
# Processing Record 10 of Set 6 | janeng
# Processing Record 11 of Set 6 | tolanaro
# Processing Record 12 of Set 6 | kujang-up
# Processing Record 13 of Set 6 | menemen
# Processing Record 14 of Set 6 | concepcion del oro
# Processing Record 15 of Set 6 | haiku-pauwela
# Processing Record 16 of Set 6 | saldanha
# Processing Record 17 of Set 6 | mirny
# Processing Record 18 of Set 6 | palo alto
# Processing Record 19 of Set 6 | kavieng
# Processing Record 20 of Set 6 | gemena
# Processing Record 21 of Set 6 | copiapo
# Processing Record 22 of Set 6 | brookings
# Processing Record 23 of Set 6 | oskarshamn
# Processing Record 24 of Set 6 | al bawiti
# Processing Record 25 of Set 6 | cidreira
# Processing Record 26 of Set 6 | praia da vitoria
# Processing Record 27 of Set 6 | korets
# Processing Record 28 of Set 6 | arraial do cabo
# Processing Record 29 of Set 6 | orrville
# Processing Record 30 of Set 6 | mao
# Processing Record 31 of Set 6 | allapalli
# Processing Record 32 of Set 6 | broome
# Processing Record 33 of Set 6 | dryden
# Processing Record 34 of Set 6 | forster
# Processing Record 35 of Set 6 | ugoofaaru
# Processing Record 36 of Set 6 | sao vicente
# Processing Record 37 of Set 6 | zomin shaharchasi
# City not found. Skipping...
# Processing Record 38 of Set 6 | kolonia
# Processing Record 39 of Set 6 | sao jose da coroa grande
# Processing Record 40 of Set 6 | st. john's
# Processing Record 41 of Set 6 | neon karlovasion
# Processing Record 42 of Set 6 | sur
# Processing Record 43 of Set 6 | howrah
# Processing Record 44 of Set 6 | northam
# Processing Record 45 of Set 6 | hafar al-batin
# Processing Record 46 of Set 6 | geraldton
# Processing Record 47 of Set 6 | pontes e lacerda
# Processing Record 48 of Set 6 | yaren
# Processing Record 49 of Set 6 | inirida
# Processing Record 0 of Set 7 | swakopmund
# Processing Record 1 of Set 7 | kingston
# Processing Record 2 of Set 7 | farmington
# Processing Record 3 of Set 7 | bathsheba
# Processing Record 4 of Set 7 | rosarito
# Processing Record 5 of Set 7 | chibougamau
# Processing Record 6 of Set 7 | villefranche-de-rouergue
# Processing Record 7 of Set 7 | atafu village
# Processing Record 8 of Set 7 | kapa'a
# Processing Record 9 of Set 7 | papao
# Processing Record 10 of Set 7 | ketchikan
# Processing Record 11 of Set 7 | saint-philippe
# Processing Record 12 of Set 7 | kudahuvadhoo
# Processing Record 13 of Set 7 | vegachi
# Processing Record 14 of Set 7 | koryazhma
# Processing Record 15 of Set 7 | mishelevka
# Processing Record 16 of Set 7 | roma
# Processing Record 17 of Set 7 | asubulaq
# Processing Record 18 of Set 7 | luderitz
# Processing Record 19 of Set 7 | port moresby
# Processing Record 20 of Set 7 | hamilton
# Processing Record 21 of Set 7 | iranshahr
# Processing Record 22 of Set 7 | dapa
# Processing Record 23 of Set 7 | tabuk
# Processing Record 24 of Set 7 | darreh shahr
# City not found. Skipping...
# Processing Record 25 of Set 7 | wainwright
# Processing Record 26 of Set 7 | kodok
# City not found. Skipping...
# Processing Record 27 of Set 7 | fedorovskiy
# Processing Record 28 of Set 7 | georgetown
# Processing Record 29 of Set 7 | ixtapa
# Processing Record 30 of Set 7 | siwa oasis
# Processing Record 31 of Set 7 | shimoda
# Processing Record 32 of Set 7 | dunedin
# Processing Record 33 of Set 7 | dazhong
# Processing Record 34 of Set 7 | kapuskasing
# Processing Record 35 of Set 7 | iskateley
# Processing Record 36 of Set 7 | waddan
# Processing Record 37 of Set 7 | neiafu
# Processing Record 38 of Set 7 | puerto armuelles
# Processing Record 39 of Set 7 | tura
# Processing Record 40 of Set 7 | hadibu
# Processing Record 41 of Set 7 | burang
# Processing Record 42 of Set 7 | pakokku
# Processing Record 43 of Set 7 | tsiombe
# Processing Record 44 of Set 7 | la mitra
# Processing Record 45 of Set 7 | mokhotlong
# Processing Record 46 of Set 7 | moengo
# Processing Record 47 of Set 7 | sofifi
# City not found. Skipping...
# Processing Record 48 of Set 7 | cockburn town
# Processing Record 49 of Set 7 | leava
# Processing Record 0 of Set 8 | nurmijarvi
# Processing Record 1 of Set 8 | tangancicuaro de arista
# Processing Record 2 of Set 8 | yigo village
# Processing Record 3 of Set 8 | posto fiscal rolim de moura
# Processing Record 4 of Set 8 | mukalla
# Processing Record 5 of Set 8 | zouerate
# Processing Record 6 of Set 8 | meadow lakes
# Processing Record 7 of Set 8 | lae
# Processing Record 8 of Set 8 | niafunke
# Processing Record 9 of Set 8 | sukhothai
# Processing Record 10 of Set 8 | mar del plata
# Processing Record 11 of Set 8 | hiratacho
# Processing Record 12 of Set 8 | rimus
# Processing Record 13 of Set 8 | auki
# Processing Record 14 of Set 8 | tanjung pandan
# Processing Record 15 of Set 8 | kulhudhuffushi
# Processing Record 16 of Set 8 | gulf shores
# Processing Record 17 of Set 8 | pisco
# Processing Record 18 of Set 8 | alofi
# Processing Record 19 of Set 8 | tobelo
# Processing Record 20 of Set 8 | kharkhorin
# Processing Record 21 of Set 8 | makarov
# Processing Record 22 of Set 8 | aoulef
# Processing Record 23 of Set 8 | wittstock
# Processing Record 24 of Set 8 | buka
# Processing Record 25 of Set 8 | callao
# Processing Record 26 of Set 8 | naro moru
# Processing Record 27 of Set 8 | el calafate
# Processing Record 28 of Set 8 | fairmont
# Processing Record 29 of Set 8 | general villegas
# Processing Record 30 of Set 8 | ahlat
# Processing Record 31 of Set 8 | torghay
# Processing Record 32 of Set 8 | mount gambier
# Processing Record 33 of Set 8 | malabar
# Processing Record 34 of Set 8 | mata-utu
# Processing Record 35 of Set 8 | tanrake village
# City not found. Skipping...
# Processing Record 36 of Set 8 | labrador city
# Processing Record 37 of Set 8 | mwatate
# Processing Record 38 of Set 8 | mili
# Processing Record 39 of Set 8 | areia
# Processing Record 40 of Set 8 | mogadishu
# Processing Record 41 of Set 8 | yanbu
# Processing Record 42 of Set 8 | vila franca do campo
# Processing Record 43 of Set 8 | lorengau
# Processing Record 44 of Set 8 | san luis de la loma
# Processing Record 45 of Set 8 | labuan
# Processing Record 46 of Set 8 | lodwar
# Processing Record 47 of Set 8 | west fargo
# Processing Record 48 of Set 8 | nema
# Processing Record 49 of Set 8 | coquimbo
# Processing Record 0 of Set 9 | kutum
# Processing Record 1 of Set 9 | san rafael del yuma
# Processing Record 2 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 3 of Set 9 | matoury
# Processing Record 4 of Set 9 | sisimiut
# Processing Record 5 of Set 9 | borgo
# Processing Record 6 of Set 9 | djibo
# Processing Record 7 of Set 9 | pangai
# Processing Record 8 of Set 9 | levelland
# Processing Record 9 of Set 9 | nuku'alofa
# Processing Record 10 of Set 9 | el banco
# Processing Record 11 of Set 9 | argo
# Processing Record 12 of Set 9 | arkhipo-osipovka
# Processing Record 13 of Set 9 | malvan
# Processing Record 14 of Set 9 | calama
# Processing Record 15 of Set 9 | dieppe
# Processing Record 16 of Set 9 | eldama ravine
# Processing Record 17 of Set 9 | camana
# Processing Record 18 of Set 9 | gebeit
# Processing Record 19 of Set 9 | itacare
# Processing Record 20 of Set 9 | kuala pilah
# Processing Record 21 of Set 9 | harenkarspel
# Processing Record 22 of Set 9 | bria
# Processing Record 23 of Set 9 | kearney
# Processing Record 24 of Set 9 | latakia
# Processing Record 25 of Set 9 | tibanbang
# Processing Record 26 of Set 9 | takoradi
# Processing Record 27 of Set 9 | itupiranga
# Processing Record 28 of Set 9 | pucallpa
# Processing Record 29 of Set 9 | huoqiu chengguanzhen
# Processing Record 30 of Set 9 | nouadhibou
# Processing Record 31 of Set 9 | erwin
# Processing Record 32 of Set 9 | rumonge
# Processing Record 33 of Set 9 | new norfolk
# Processing Record 34 of Set 9 | cova figueira
# Processing Record 35 of Set 9 | mount isa
# Processing Record 36 of Set 9 | darnah
# Processing Record 37 of Set 9 | cadale
# Processing Record 38 of Set 9 | luganville
# Processing Record 39 of Set 9 | nova vicosa
# Processing Record 40 of Set 9 | kone
# Processing Record 41 of Set 9 | fort bragg
# Processing Record 42 of Set 9 | sinabang
# Processing Record 43 of Set 9 | vikulovo
# Processing Record 44 of Set 9 | nova sintra
# Processing Record 45 of Set 9 | videira
# Processing Record 46 of Set 9 | mandalgovi
# Processing Record 47 of Set 9 | daru
# Processing Record 48 of Set 9 | black point
# Processing Record 49 of Set 9 | kulia village

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()

# %%
# Display sample data
city_data_df.head()

# %%
import os

# Create the output_data directory if it doesn't exist
output_data_dir = 'output_data'
os.makedirs(output_data_dir, exist_ok=True)

# Save the CSV file in the output_data directory
csv_path = os.path.join(output_data_dir, 'cities.csv')
city_data_df.to_csv(csv_path, index_label="City_ID")


# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(C)')
plt.title('City Latitude vs.Temperature')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('City Latitude vs. Humidity')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs.Cloudiness')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
plt.title('City Latitude vs.Wind Speed')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_reg(x_axis, y_axis,eq_loc):  
    correlation = st.pearsonr(x_axis,y_axis)
    p_slope, p_int, p_r, p_p, p_std_err = st.linregress(x_axis, y_axis)
    p_fit = p_slope * x_axis + p_int
    eq= f"y ={p_slope: .2f}x +{ p_int: .2f}"
       
    #Plot the line
    plt.scatter(x_axis, y_axis ,marker="o")
    plt.plot(x_axis,p_fit,"--", color='red')
    plt.annotate(eq, eq_loc, fontsize=12, color='red')
    print(f"The r-value between {x_axis.name} and {y_axis.name} is {round(correlation[0],2)}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], (10, -10))
plt.xlabel('Latitude')
plt.ylabel('Temperature(C)')

# %%
# Linear regression on Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], (-30, 5))
plt.xlabel('Latitude')
plt.ylabel('Temperature(C)')

# %% [markdown]
# **Discussion about the linear relationship:** The northern and southern hemispheres are opposite of one another. Meaning that in the northern hemisphere - the higher the altitude the colder the weather, while the southern hemisphere is the opposite of that.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Humidity'],(55, 10))
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')

# %%
# Southern Hemisphere
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Humidity'],(-50, 25))
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')

# %% [markdown]
# **Discussion about the linear relationship:** Both northern and southern hemispheres have a weak correlation with latitude and humidity

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'],(50, 50))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'],(-50, 65))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')

# %% [markdown]
# **Discussion about the linear relationship:**

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'],(10, 12))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')

# %%
# Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'],(-50, 9))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
